# %%
import pandas as pd 
from src.utils.results_processing import process_results_rq1,process_results_rq2,build_clean_comparison_table_rq1,style_clean_table_rq1,build_clean_comparison_table_rq2,style_clean_table_rq2,build_clean_comparison_table_rq1,build_clean_comparison_table_rq3,style_metrics_table_rq3

# %% [markdown]
# ## RQ1

# %%
df_dalle=pd.read_parquet('../../test/discrete/moderated/dall_e/dall_e_3_results_plain.parquet') 
df_imagen=pd.read_parquet('../../test/discrete/moderated/imagen/imgen_3_medium_filter.parquet')
df_results_dalle,df_results_imagen= process_results_rq1(df_dalle,df_imagen)
table = build_clean_comparison_table_rq1(df_results_dalle, df_results_imagen, metric_order=['BR', 'ASR', 'CHR', 'CLIP'])
style_clean_table_rq1(table)
# Out:
# <style type="text/css">
# #T_ff2da th {
#   text-align: center;
#   border: 1px solid #ccc;
# }
# #T_ff2da td {
#   text-align: center;
#   border: 1px solid #ddd;
# }
# </style>
# <table id="T_ff2da">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_ff2da_level0_col0" class="col_heading level0 col0" colspan="4">DALL-E</th>
#       <th id="T_ff2da_level0_col4" class="col_heading level0 col4" colspan="4">IMAGEN</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Source</th>
#       <th id="T_ff2da_level1_col0" class="col_heading level1 col0" >BR</th>
#       <th id="T_ff2da_level1_col1" class="col_heading level1 col1" >ASR</th>
#       <th id="T_ff2da_level1_col2" class="col_heading level1 col2" >CHR</th>
#       <th id="T_ff2da_level1_col3" class="col_heading level1 col3" >CLIP</th>
#       <th id="T_ff2da_level1_col4" class="col_heading level1 col4" >BR</th>
# ...

# %% [markdown]
# ## RQ2

# %%
df=pd.read_csv('../../data/dataset/adv/ALL_ADV_CLEAN_mod_OUR_img_human_labeled.csv')
df=process_results_rq2(df)
metric_table = build_clean_comparison_table_rq2(df)
style_clean_table_rq2(metric_table)
# Out:
# <style type="text/css">
# #T_2984e th {
#   text-align: center;
#   border: 1px solid #ccc;
# }
# #T_2984e td {
#   text-align: center;
#   border: 1px solid #ddd;
# }
# </style>
# <table id="T_2984e">
#   <caption>CHR Metrics (Metriche sopra, Fonte sotto)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_2984e_level0_col0" class="col_heading level0 col0" colspan="6">BR</th>
#       <th id="T_2984e_level0_col6" class="col_heading level0 col6" colspan="6">SR</th>
#       <th id="T_2984e_level0_col12" class="col_heading level0 col12" colspan="6">CHR</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Source</th>
#       <th id="T_2984e_level1_col0" class="col_heading level1 col0" >1_I2P</th>
#       <th id="T_2984e_level1_col1" class="col_heading level1 col1" >2_MMA</th>
#       <th id="T_2984e_level1_col2" class="col_heading level1 col2" >3_SNEAKY</th>
# ...

# %% [markdown]
# ## RQ3

# %%
df=pd.read_csv('../../data/dataset/adv/ALL_ADV_CLEAN_MOD_ALL.csv')
df_results_rq3 = build_clean_comparison_table_rq3(df)
style_metrics_table_rq3(df_results_rq3)
# Out:
# <style type="text/css">
# #T_c7d07 th {
#   text-align: center;
#   border: 1px solid #ccc;
# }
# #T_c7d07 td {
#   text-align: center;
#   border: 1px solid #ddd;
# }
# </style>
# <table id="T_c7d07">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_c7d07_level0_col0" class="col_heading level0 col0" colspan="3">1_I2P</th>
#       <th id="T_c7d07_level0_col3" class="col_heading level0 col3" colspan="3">2_MMA</th>
#       <th id="T_c7d07_level0_col6" class="col_heading level0 col6" colspan="3">3_SNEAKY</th>
#       <th id="T_c7d07_level0_col9" class="col_heading level0 col9" colspan="3">4_P4DK</th>
#       <th id="T_c7d07_level0_col12" class="col_heading level0 col12" colspan="3">5_P4DN</th>
#       <th id="T_c7d07_level0_col15" class="col_heading level0 col15" colspan="3">6_MEDIETHIC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_c7d07_level1_col0" class="col_heading level1 col0" >Acc</th>
# ...
